# %%
# 패키지 설치
# !pip install "numpy<2.0" "scipy<1.13" ultralytics scikit-learn sahi -U -q

print("✅ 패키지 설치 완료")
# !nvidia-smi
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 53.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 109.8 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 32.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.6 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 9.1 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.8.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# ✅ 패키지 설치 완료
# Sat Dec 13 09:49:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6567.6/8062.4 GB disk)

# %%
# GitHub 클론
import os

if os.path.exists('MCA'):
    # !rm -rf MCA

# !git clone https://github.com/ICT-Top-Bottom/MCA.git
# %cd MCA
# !ls -la roboflow/
# Out:
# Cloning into 'MCA'...
# remote: Enumerating objects: 3948, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3948 (delta 0), reused 0 (delta 0), pack-reused 3944 (from 4)
# Receiving objects: 100% (3948/3948), 2.64 GiB | 56.54 MiB/s, done.
# Resolving deltas: 100% (212/212), done.
# Updating files: 100% (2033/2033), done.
# /kaggle/working/MCA
# total 28
# drwxr-xr-x  4 root root 4096 Dec 13 09:50 .
# drwxr-xr-x 15 root root 4096 Dec 13 09:50 ..
# -rw-r--r--  1 root root  286 Dec 13 09:50 data.yaml
# -rw-r--r--  1 root root  134 Dec 13 09:50 README.dataset.txt
# -rw-r--r--  1 root root  989 Dec 13 09:50 README.roboflow.txt
# drwxr-xr-x  4 root root 4096 Dec 13 09:50 train
# drwxr-xr-x  4 root root 4096 Dec 13 09:50 valid

# %%
# 데이터 확인
from pathlib import Path
from collections import Counter

train_images = Path('roboflow/train/images')
train_labels = Path('roboflow/train/labels')
valid_images = Path('roboflow/valid/images')
valid_labels = Path('roboflow/valid/labels')

train_count = len(list(train_images.glob('*.jpg')))
valid_count = len(list(valid_images.glob('*.jpg')))
total = train_count + valid_count

print(f"Train: {train_count} ({train_count/total*100:.1f}%)")
print(f"Valid: {valid_count} ({valid_count/total*100:.1f}%)")
print(f"Total: {total}")

# 클래스 분포 확인
class_counts = Counter()
for label_file in train_labels.glob('*.txt'):
    with open(label_file, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= 5:
                cls = int(float(parts[0]))
                class_counts[cls] += 1

class_names = {0: 'combined', 1: 'empty', 2: 'fully'}
print("\nClass Distribution (Train):")
for cls_id, count in sorted(class_counts.items()):
    percentage = count / sum(class_counts.values()) * 100
    print(f"  {class_names[cls_id]}: {count} ({percentage:.1f}%)")
# Out:
# Train: 316 (80.2%)
# Valid: 78 (19.8%)
# Total: 394
#
# Class Distribution (Train):
#   combined: 139 (39.3%)
#   empty: 99 (28.0%)
#   fully: 116 (32.8%)

# %%
# data.yaml 생성
import yaml

current_dir = os.getcwd()

data_yaml = {
    'path': f'{current_dir}/roboflow',
    'train': 'train/images',
    'val': 'valid/images',
    'nc': 3,
    'names': ['combined_cart', 'empty_cart', 'fully_cart']
}

with open('data.yaml', 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print(f"Dataset path: {current_dir}/roboflow")
print("\ndata.yaml:")
# !cat data.yaml
# Out:
# Dataset path: /kaggle/working/MCA/roboflow
#
# data.yaml:
# names:
# - combined_cart
# - empty_cart
# - fully_cart
# nc: 3
# path: /kaggle/working/MCA/roboflow
# train: train/images
# val: valid/images

# %%
from ultralytics import YOLO

# 모델: V4에서 썼던 small 모델 사용
model = YOLO('yolo11s-seg.pt') 

results = model.train(
    data='data.yaml',
    
    # --- 1. V4의 성공 방정식 (탐지력 확보) ---
    epochs=200,          # 150 -> 200 (충분한 학습)
    batch=8,             # 1280px이라 메모리 때문에 8 유지 (작지만 고해상도가 깡패)
    imgsz=1280,          # ⭐ 핵심: 고해상도로 철망 디테일 살림 (오탐 제거의 열쇠)
    
    # --- 2. V4의 약점 보완 (분류 정확도) ---
    # V4는 cls=0.5 였습니다. 이걸 대폭 올려서 "틀리면 죽는다"는 신호를 줍니다.
    cls=4.0,             # (기본 0.5 -> 4.0) 분류 오차에 엄청난 페널티 부여
    box=7.5,             # 박스 위치는 기존 유지
    
    # --- 3. 오분류 방지 증강 설정 ---
    # Mixup은 겹친 이미지를 만드는데, 이게 '겹친 카트' 학습을 방해했을 수 있습니다.
    # V4에선 0.15였지만, 분류 정확도를 위해 조금 낮춥니다.
    mixup=0.05,          # 0.15 -> 0.05 (아주 살짝만)
    mosaic=1.0,          # 유지 (작은 객체 탐지에 도움)
    
    # --- 4. 미세 조정 (Fine-tuning) ---
    close_mosaic=20,     # 마지막 20 에폭은 증강 끄고 정 정밀 학습
    dropout=0.1,         # 과적합 방지용 소량 첨가
    
    # 세그멘테이션 마스크
    mask_ratio=1,        # 철망 디테일 유지를 위해 1 권장 (메모리 부족하면 4로 타협)
    overlap_mask=True,
    
    project='runs/segment',
    name='yolo11s_v7_highres_cls_focus',
    exist_ok=True,
    plots=True
)

print("학습이 완료되었느니라.")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s-seg.pt to 'yolo11s-seg.pt': 100% ━━━━━━━━━━━━ 19.7MB 139.5MB/s 0.1s1s<0.1s
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=20, cls=4.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.1, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=1, max_det=300, mixup=0.05, mode=train, model=yolo11s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11s_v7_highres_cls_focus, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/segment, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1475065  ultralytics.nn.modules.head.Segment          [3, 32, 128, [128, 256, 512]]
# YOLO11s-seg summary: 203 layers, 10,083,449 parameters, 10,083,433 gradients, 33.1 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 69.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1640.7±595.9 MB/s, size: 57.2 KB)
# train: Scanning /kaggle/working/MCA/roboflow/train/labels... 316 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 316/316 1.3Kit/s 0.2s<0.1s
# train: New cache created: /kaggle/working/MCA/roboflow/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 818.2±582.4 MB/s, size: 53.6 KB)
# val: Scanning /kaggle/working/MCA/roboflow/valid/labels... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78 1.2Kit/s 0.1s
# val: New cache created: /kaggle/working/MCA/roboflow/valid/labels.cache
# Plotting labels to /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      9.59G      1.863      4.504      60.62      2.323         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.4s1.6ss
#                    all         78         85    0.00531      0.139     0.0164    0.00397    0.00369     0.0924    0.00793    0.00213
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      9.73G      1.868      3.729      25.24      2.349         15       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 26.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.2s0.9s
#                    all         78         85      0.236      0.206     0.0802     0.0199      0.245      0.164     0.0777     0.0185
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      9.62G      1.964      3.541      20.58      2.456          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 26.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.4s0.9s
#                    all         78         85      0.064      0.134     0.0296    0.00828     0.0626      0.129     0.0339     0.0085
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      9.71G      2.102      4.376      20.54      2.582          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 28.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4it/s 3.5s0.9s
#                    all         78         85      0.509       0.28      0.158     0.0457      0.527      0.244      0.157     0.0492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      9.72G       2.07      3.698      19.85       2.53          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.3s0.9s
#                    all         78         85      0.488      0.138      0.133     0.0386      0.133     0.0817     0.0416     0.0085
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      9.65G      2.005      3.612      18.75      2.514         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s0.8s
#                    all         78         85      0.259      0.269        0.1     0.0247      0.407     0.0464     0.0295    0.00649
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      9.66G      2.029      3.755         19      2.491         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s0.8s
#                    all         78         85      0.332      0.367      0.267      0.093      0.349      0.337      0.224     0.0631
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      9.69G      1.925      3.599      18.17      2.394         14       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.4s0.9s
#                    all         78         85      0.139      0.195     0.0894     0.0236       0.15      0.244      0.103     0.0256
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      9.75G      1.912      3.457      17.54       2.39         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.4s0.9s
#                    all         78         85      0.182      0.167      0.111     0.0359      0.124      0.237     0.0597     0.0134
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      9.72G      1.821       3.34      16.23      2.338         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s0.9s
#                    all         78         85      0.451      0.477      0.446      0.157      0.451      0.477      0.434       0.17
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      9.62G      1.882      3.415      16.43       2.38          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.2s0.9s
#                    all         78         85      0.461      0.545      0.519      0.198      0.372      0.471      0.442      0.155
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      9.64G      1.899      3.493      17.26      2.326         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.5it/s 3.3s0.9s
#                    all         78         85      0.274      0.292      0.259     0.0971      0.214      0.287       0.22     0.0844
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      9.64G      1.858       3.55      16.83      2.322         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s0.8s
#                    all         78         85      0.453      0.448      0.447      0.153      0.391      0.464      0.464      0.161
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      14/200       9.6G       1.79      3.441      15.79      2.296          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.8s
#                    all         78         85      0.505      0.324       0.34       0.11        0.6      0.207      0.247     0.0577
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      9.73G       1.79      3.279      15.42      2.266          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s0.9s
#                    all         78         85      0.281       0.41      0.275     0.0842      0.309      0.412      0.292      0.091
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      16/200       9.7G      1.727      3.208      14.63       2.24          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.533      0.572       0.54      0.203      0.586      0.587      0.576      0.216
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      9.71G      1.742      3.216      14.53      2.244          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.389      0.461      0.295      0.119      0.315       0.39      0.222     0.0805
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      9.76G      1.804      3.331      15.44      2.287         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.0s0.8s
#                    all         78         85      0.671      0.558       0.63       0.27      0.709       0.53      0.641      0.256
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      9.63G      1.679      3.208      14.41       2.18          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.8s
#                    all         78         85      0.677      0.571      0.683      0.263      0.654      0.547      0.609      0.238
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      20/200       9.7G      1.715      3.208      14.26      2.188         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.668      0.578      0.635      0.224      0.699      0.602      0.654      0.251
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      9.71G      1.675      3.152      13.66      2.166          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.703      0.608      0.696      0.299      0.703      0.608      0.663       0.28
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      9.65G        1.6      3.167      14.31      2.137          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.625      0.753      0.767      0.345      0.632      0.729      0.742      0.321
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      9.75G        1.6      3.078      13.53      2.113          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.8s
#                    all         78         85       0.82      0.585      0.692      0.297       0.65      0.596      0.659       0.32
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      9.71G      1.579      3.121      12.65      2.078         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.684      0.751      0.788      0.319      0.708      0.742      0.786      0.311
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      25/200      9.68G      1.609       3.06      12.62      2.101         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.804      0.656      0.799      0.356      0.841      0.678      0.815      0.362
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      9.71G      1.601      3.074      12.76      2.098          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.755      0.653      0.789      0.345      0.731      0.622      0.716      0.343
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      9.66G      1.642      3.049      12.86      2.102          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.797      0.656       0.74      0.329      0.783      0.677      0.754       0.31
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      9.66G      1.602      3.065      13.36      2.108         14       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.744      0.595      0.713      0.322      0.739      0.602      0.708      0.336
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      9.77G      1.556      3.098      12.61       2.06          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.8s
#                    all         78         85      0.819      0.697      0.767      0.338      0.806      0.685      0.762      0.316
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      30/200      9.67G      1.568      3.097      12.51      2.064         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.0s0.8s
#                    all         78         85      0.629      0.657      0.669      0.335      0.639      0.691       0.69      0.328
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      9.62G      1.484      3.002      12.07      2.009          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.766      0.788      0.831      0.372      0.766      0.788      0.818      0.399
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      9.71G      1.622      3.034      12.68      2.119          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.785      0.681      0.765      0.352      0.818      0.667      0.767      0.351
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      9.74G      1.539          3      11.86      2.045         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.733      0.634      0.757      0.343      0.726      0.622      0.724      0.336
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      9.68G      1.493      2.907      11.32      1.966         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.882      0.774      0.856      0.405      0.886      0.771      0.841      0.392
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      9.67G      1.501      2.924      11.56      2.031          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.763      0.729      0.784      0.357       0.81      0.695      0.808      0.384
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      9.67G      1.418      2.888      10.72      1.956         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.738      0.799      0.816      0.375       0.74      0.798      0.807      0.349
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      9.62G      1.493      2.931      11.27      2.061          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.725      0.781      0.814      0.348      0.701      0.779      0.787      0.349
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      38/200      9.69G      1.501      2.902      11.55      1.981         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.84      0.703      0.844      0.384      0.831      0.691      0.824      0.389
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      9.65G      1.489      2.875      11.38      2.005          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.8s
#                    all         78         85      0.791       0.76      0.842      0.378      0.791       0.73      0.801      0.368
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      9.64G      1.407      2.822      10.49      1.932         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.732      0.649      0.749      0.334      0.742      0.661       0.76      0.359
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      41/200       9.7G      1.512       2.99      11.53      2.031         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.757      0.776      0.822      0.412      0.741      0.752      0.784      0.361
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      9.62G      1.453      2.864      11.12      1.953         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.808      0.744      0.823      0.382      0.792      0.733      0.767      0.373
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      9.75G      1.475      2.796      11.06      1.975          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.811      0.827      0.894      0.441      0.811      0.827      0.883      0.433
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      9.63G      1.385      2.732      10.63      1.938          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.838      0.816      0.879      0.419       0.88      0.764      0.868      0.452
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      9.61G       1.42      2.776      10.56      1.947          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.879      0.644      0.758      0.359      0.879      0.644      0.749      0.357
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      9.61G      1.447      2.684      10.52      1.951         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.821      0.821      0.868      0.431      0.822      0.821      0.829      0.389
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      9.72G      1.432      2.662       10.1      1.931          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.73      0.902      0.873      0.462      0.715      0.876      0.851      0.421
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      9.79G      1.468      2.903      10.73      1.972         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.851       0.84      0.903      0.467      0.828      0.864       0.88      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      9.61G      1.334        2.7      10.12      1.838         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.778      0.796      0.872      0.424      0.761      0.788      0.817       0.43
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      9.74G      1.313       2.72      10.21      1.858          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.818      0.799      0.894      0.476      0.784      0.775      0.867      0.449
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      9.73G      1.394      2.737      9.959      1.888          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.807      0.742      0.854      0.444      0.808      0.738      0.837      0.437
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      9.68G      1.388      2.666      9.722      1.892         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.874      0.739      0.884      0.492      0.867      0.725      0.833      0.429
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      53/200       9.7G      1.356      2.594      9.845      1.857         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.771      0.797      0.833      0.464      0.761      0.786      0.822      0.429
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      9.64G      1.335      2.756      9.628      1.856          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.768      0.835      0.883      0.483      0.809      0.786      0.885      0.482
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      55/200      9.73G      1.382      2.782      10.29      1.924          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.845      0.836      0.906      0.499      0.845      0.836      0.907      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      9.62G      1.401      2.763      9.882      1.878         14       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.862      0.823      0.909      0.505      0.862      0.823      0.894      0.509
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      57/200      9.73G      1.356      2.676      9.464      1.856         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.9s0.8s
#                    all         78         85      0.821      0.811      0.879      0.476      0.808      0.799      0.852      0.456
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      58/200      9.72G      1.331      2.685      9.199      1.846         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.842      0.806      0.897      0.494      0.827      0.794      0.887      0.487
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      9.68G      1.317      2.621      9.441      1.815         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.915      0.844      0.938      0.516      0.932      0.821      0.913      0.492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      9.67G      1.313      2.701      9.792      1.839         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.904      0.749      0.873      0.486      0.887      0.737      0.848       0.47
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      9.57G      1.241      2.512      8.711      1.753         13       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.84      0.807      0.872      0.522      0.849      0.804      0.854      0.459
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      9.75G      1.239      2.569      8.775      1.783         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.856      0.877      0.915      0.533      0.871      0.859      0.903      0.506
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      9.67G      1.315      2.514      9.002      1.824          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.859      0.877      0.901      0.532      0.893        0.8      0.863      0.495
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      9.69G      1.276      2.622      9.189       1.83          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.903      0.835      0.908      0.481      0.903      0.835      0.905      0.489
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      9.67G      1.204      2.401      8.538      1.758         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.785      0.808      0.889      0.519      0.807      0.834       0.89      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      9.64G      1.281      2.521      9.093      1.792         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.908      0.842      0.923       0.53      0.925      0.824      0.913      0.514
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      9.69G      1.268      2.595      8.723       1.79         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.91      0.836      0.929      0.532       0.91      0.836      0.922       0.51
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      68/200       9.6G      1.259      2.517      8.464      1.762         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.834      0.789       0.88      0.478      0.833      0.794      0.874       0.43
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      9.76G      1.199      2.428      8.174      1.691         15       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.853      0.886      0.903       0.52      0.853      0.886        0.9      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      9.64G      1.274      2.506      8.757      1.752          6       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.776      0.861      0.887      0.545      0.767      0.849      0.866      0.512
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      9.59G       1.22      2.515      8.029      1.749         15       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.8s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.861      0.891      0.905      0.543      0.875       0.86      0.869      0.484
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      9.62G      1.265      2.523      8.633      1.797         16       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.876      0.816      0.888      0.532      0.876      0.816      0.884      0.517
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      9.76G      1.235      2.479      8.712      1.771         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.833      0.894      0.936      0.532      0.823      0.883       0.91      0.488
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      9.78G      1.219      2.411      8.414      1.755         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.878      0.835      0.904       0.52      0.857      0.823      0.897      0.507
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      9.65G      1.242      2.509      8.388      1.762          8       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.895      0.846       0.91      0.528      0.898      0.819       0.89      0.505
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      9.63G      1.175      2.315      7.917      1.719         12       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.886      0.875      0.935      0.528      0.874      0.863      0.919      0.518
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      9.63G      1.225       2.38      7.853      1.731         14       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.89      0.851      0.889      0.541      0.876      0.839      0.862      0.512
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      9.58G      1.151       2.41       7.64      1.671         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.881       0.87      0.943      0.546      0.867      0.811      0.878       0.52
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.957      0.951       0.98      0.682      0.945      0.939      0.959      0.626
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     175/200      9.62G     0.8673      1.786       4.76      1.407         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.9s0.8s
#                    all         78         85      0.955      0.948      0.977      0.686      0.943      0.937      0.956      0.625
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     176/200      9.69G     0.8509      1.799      4.849       1.37         14       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.963      0.951      0.979      0.679      0.951      0.939      0.956      0.635
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     177/200      9.72G     0.9003      1.866      5.213      1.409          9       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.966      0.944      0.983      0.679      0.954      0.932      0.959      0.637
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     178/200      9.77G     0.8606      1.888       4.98      1.408         11       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.953       0.94      0.987      0.677      0.941      0.928       0.96      0.625
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     179/200      9.78G     0.8542      1.884      5.093      1.381          7       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.969      0.954       0.99      0.684      0.957      0.942      0.959      0.612
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     180/200      9.67G     0.8834      1.957      5.256      1.405         10       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 27.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.981      0.951      0.986      0.678      0.969      0.939      0.958      0.628
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     181/200      9.53G     0.9457      1.515      3.948       1.32          6       1280: 100% ━━━━━━━━━━━━ 40/40 1.4it/s 28.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.941      0.942      0.978      0.679      0.941      0.942      0.964      0.622
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     182/200      9.55G      1.008      1.503      3.962      1.313          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.9s0.8s
#                    all         78         85      0.939       0.95       0.97      0.672      0.928      0.939      0.952      0.628
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     183/200      9.51G     0.9644      1.478      3.849      1.312          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.952      0.952      0.975      0.674       0.96       0.93      0.955      0.627
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     184/200       9.5G     0.9411       1.49      3.711      1.305          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.957      0.942      0.973      0.673      0.951      0.924      0.964      0.634
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     185/200      9.54G     0.9365      1.402      3.418      1.322          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85       0.96      0.946      0.976      0.689       0.96      0.946      0.968       0.64
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     186/200      9.52G     0.9319      1.375      3.383      1.317          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.982       0.94      0.983       0.68      0.982       0.94      0.971      0.642
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     187/200      9.55G     0.9206      1.419      3.302      1.259          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.977      0.944      0.987      0.692      0.977      0.944      0.971       0.63
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     188/200      9.52G     0.9922      1.399      3.423      1.279          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.987      0.942      0.987       0.69      0.987      0.942      0.972      0.633
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     189/200       9.5G      0.921      1.387      3.475      1.294          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8s
#                    all         78         85      0.986       0.94      0.985      0.686      0.986       0.94      0.971      0.634
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     190/200      9.53G      0.874      1.367      3.168      1.251          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.975      0.948       0.98       0.69      0.974      0.941       0.97      0.645
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     191/200      9.54G     0.9084      1.382      3.651      1.256          6       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.965      0.952      0.978       0.69      0.965      0.952       0.97      0.634
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     192/200      9.56G     0.9241      1.337      3.398      1.286          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85       0.99      0.932      0.979      0.684      0.975      0.921      0.956      0.633
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     193/200      9.55G     0.9436      1.356       3.41      1.266          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.981      0.948      0.976      0.688      0.967      0.936      0.957      0.629
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     194/200      9.52G     0.9391      1.331      3.341      1.232          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.987      0.952      0.976      0.687      0.973       0.94      0.959      0.625
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     195/200      9.52G      0.881       1.32      3.207       1.26          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85       0.99      0.952      0.978      0.697      0.977       0.94       0.96      0.631
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     196/200      9.52G     0.9093      1.308      3.286      1.238          6       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.993      0.952      0.972      0.696       0.98       0.94       0.96      0.629
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     197/200      9.52G      0.887      1.364      3.185      1.233          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.992      0.951      0.972      0.704      0.979      0.939       0.96      0.637
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     198/200       9.5G     0.8842      1.338        3.2      1.203          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.993      0.952      0.971      0.705       0.98       0.94      0.959       0.64
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     199/200       9.5G     0.9121      1.335      3.352      1.232          5       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.992      0.952      0.971      0.705      0.978       0.94      0.959      0.644
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     200/200      9.52G      0.872      1.298       3.27      1.255          4       1280: 100% ━━━━━━━━━━━━ 40/40 1.5it/s 27.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all         78         85      0.992      0.952      0.978        0.7      0.992      0.952      0.972      0.645
#
# 200 epochs completed in 1.743 hours.
# Optimizer stripped from /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus/weights/last.pt, 20.7MB
# Optimizer stripped from /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus/weights/best.pt, 20.7MB
#
# Validating /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,977 parameters, 0 gradients, 32.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.4s1.2s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         78         85      0.991      0.952      0.971      0.704      0.978       0.94      0.959      0.645
#          combined_cart         22         28      0.999      0.893      0.927      0.614      0.959      0.857      0.892      0.572
#             empty_cart         29         29      0.984          1      0.995      0.787      0.984          1      0.995       0.75
#             fully_cart         27         28      0.991      0.964       0.99      0.711      0.991      0.964       0.99      0.614
# Speed: 1.0ms preprocess, 28.1ms inference, 0.0ms loss, 8.1ms postprocess per image
# Results saved to /kaggle/working/MCA/runs/segment/yolo11s_v7_highres_cls_focus
# 학습이 완료되었느니라.

# %%
# 결과 시각화
from IPython.display import Image, display

results_dir = 'runs/segment/yolo11s_v7_highres_cls_focus'

for img_name in ['results.png', 'confusion_matrix.png', 'confusion_matrix_normalized.png']:
    img_path = os.path.join(results_dir, img_name)
    if os.path.exists(img_path):
        print(f"\n{'='*60}\n{img_name}\n{'='*60}")
        display(Image(filename=img_path))
# Out:
# ============================================================
# results.png
# ============================================================
# ============================================================
# confusion_matrix.png
# ============================================================
# ============================================================
# confusion_matrix_normalized.png
# ============================================================

# %%
# 모델 검증
best_model = YOLO('runs/segment/yolo11s_v7_highres_cls_focus/weights/best.pt')
metrics = best_model.val(data='data.yaml')

print("\n" + "="*60)
print("yolo11s_v7_highres_cls_focus Performance")
print("="*60)
print(f"Box mAP50:     {metrics.box.map50:.4f}")
print(f"Box mAP50-95:  {metrics.box.map:.4f}")
print(f"Mask mAP50:    {metrics.seg.map50:.4f}")
print(f"Mask mAP50-95: {metrics.seg.map:.4f}")
print(f"Precision:     {metrics.box.mp:.4f}")
print(f"Recall:        {metrics.box.mr:.4f}")
print("="*60)

# Baseline 대비 개선율
baseline_n_seg = 0.7899  # yolo11n_seg_cctv_augmented
improvement = (metrics.box.map - baseline_n_seg) / baseline_n_seg * 100
print(f"\nYOLO11n-seg 대비 Box mAP50-95 개선: {improvement:+.2f}%")

# 클래스별 성능
print("\nPer-Class Performance (Box):")
class_names = ['combined', 'empty', 'fully']
if hasattr(metrics.box, 'maps'):
    for i, name in enumerate(class_names):
        print(f"  {name}: mAP50-95 = {metrics.box.maps[i]:.4f}")

print("\nPer-Class Performance (Mask):")
if hasattr(metrics.seg, 'maps'):
    for i, name in enumerate(class_names):
        print(f"  {name}: mAP50-95 = {metrics.seg.maps[i]:.4f}")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,977 parameters, 0 gradients, 32.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1530.6±584.1 MB/s, size: 51.6 KB)
# val: Scanning /kaggle/working/MCA/roboflow/valid/labels.cache... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78 155.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.7s1.9ss
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         78         85      0.992      0.952      0.971      0.705      0.978       0.94      0.959      0.641
#          combined_cart         22         28      0.998      0.893      0.927      0.614      0.959      0.857      0.892      0.565
#             empty_cart         29         29      0.984          1      0.995      0.787      0.984          1      0.995      0.742
#             fully_cart         27         28      0.992      0.964       0.99      0.713      0.992      0.964       0.99      0.615
# Speed: 15.1ms preprocess, 52.3ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/MCA/runs/segment/val
#
# ============================================================
# yolo11s_v7_highres_cls_focus Performance
# ============================================================
# Box mAP50:     0.9709
# Box mAP50-95:  0.7047
# Mask mAP50:    0.9591
# Mask mAP50-95: 0.6407
# Precision:     0.9915
# Recall:        0.9524
# ============================================================
#
# YOLO11n-seg 대비 Box mAP50-95 개선: -10.79%
#
# Per-Class Performance (Box):
#   combined: mAP50-95 = 0.6142
#   empty: mAP50-95 = 0.7865
#   fully: mAP50-95 = 0.7133
#
# Per-Class Performance (Mask):
#   combined: mAP50-95 = 0.5655
#   empty: mAP50-95 = 0.7419
#   fully: mAP50-95 = 0.6148

# %%
# GitHub 푸시
from getpass import getpass
import json
from datetime import datetime
import subprocess
import shutil

USER_EMAIL = "24457545yong@gmail.com"
USER_NAME = "TaeWoongYoun"
REPO_OWNER = "ICT-Top-Bottom"
REPO_NAME = "MCA"
REPO_URL = f"https://github.com/{REPO_OWNER}/{REPO_NAME}.git"

print("GitHub Token:")
TOKEN = getpass()

results_output = 'yolo11s_v7_highres_cls_focus'
train_run_dir = 'runs/segment/yolo11s_v7_highres_cls_focus'

if os.path.exists(results_output):
    shutil.rmtree(results_output)
os.makedirs(results_output)

def safe_copy(src, dst):
    try:
        shutil.copy(src, dst)
        print(f"  ✓ {os.path.basename(src)}")
        return True
    except FileNotFoundError:
        print(f"  ✗ {os.path.basename(src)}")
        return False

print("\n결과 파일 복사...")
safe_copy(f'{train_run_dir}/weights/best.pt', results_output)
safe_copy(f'{train_run_dir}/weights/last.pt', results_output)
safe_copy(f'{train_run_dir}/results.png', results_output)
safe_copy(f'{train_run_dir}/results.csv', results_output)
safe_copy(f'{train_run_dir}/confusion_matrix.png', results_output)
safe_copy(f'{train_run_dir}/confusion_matrix_normalized.png', results_output)
safe_copy('data.yaml', results_output)

report = {
    "model": "yolo11s_v7_highres_cls_focus",
    "date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "objective": "Minimize False Positives while maintaining small object detection",
    "strategy": "Conservative augmentation + close_mosaic fine-tuning + 768px resolution",
    "key_improvements": [
        "Mixup OFF (카트 겹침 혼동 제거) ⭐⭐⭐",
        "close_mosaic=20 (실제 이미지 fine-tuning) ⭐⭐⭐",
        "768px resolution (균형잡힌 해상도) ⭐",
        "보수적 증강 (degrees=10, scale=0.4) ⭐",
        "flipud OFF (CCTV 환경 특화)"
    ],
    "next_steps": [
        "SAHI (Slicing Aided Hyper Inference) 적용",
        "conf=0.40~0.45로 추론 (오탐 제거)",
        "testImage로 실전 테스트"
    ],
    "config": {
        "model": "yolo11s-seg",
        "epochs": 200,
        "batch": 24,
        "imgsz": 768,
        "device": "[0, 1]",
        "patience": 50,
        "optimizer": "auto",
        "overlap_mask": True,
        "close_mosaic": 20,
        "mixup": 0.0,
        "degrees": 10.0,
        "scale": 0.4,
        "flipud": 0.0
    },
    "metrics": {
        "box_mAP50": float(metrics.box.map50),
        "box_mAP50-95": float(metrics.box.map),
        "mask_mAP50": float(metrics.seg.map50),
        "mask_mAP50-95": float(metrics.seg.map),
        "precision": float(metrics.box.mp),
        "recall": float(metrics.box.mr)
    },
    "baseline_comparison": {
        "baseline_yolo11n_seg": baseline_n_seg,
        "improvement_percent": round(improvement, 2)
    },
    "dataset": {
        "train": train_count,
        "valid": valid_count,
        "total": total
    }
}

with open(f'{results_output}/performance_report.json', 'w') as f:
    json.dump(report, f, indent=2)

print("\nGitHub 푸시...")

if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

subprocess.run(['git', 'clone', '--depth', '1', REPO_URL], check=True)

destination_dir = os.path.join(REPO_NAME, 'yolo11s_v7_highres_cls_focus')
if os.path.exists(destination_dir):
    shutil.rmtree(destination_dir)
shutil.copytree(results_output, destination_dir)

os.chdir(REPO_NAME)
subprocess.run(['git', 'config', '--global', 'user.email', USER_EMAIL], check=True)
subprocess.run(['git', 'config', '--global', 'user.name', USER_NAME], check=True)

subprocess.run(['git', 'add', '.'], check=True)

commit_msg = f"add: yolo11s_v7_highres_cls_focus (balanced, FP reduction, improvement: {improvement:+.2f}%)"
subprocess.run(['git', 'commit', '-m', commit_msg], check=True)

push_url = f"https://{USER_NAME}:{TOKEN}@github.com/{REPO_OWNER}/{REPO_NAME}.git"
subprocess.run(['git', 'push', push_url], check=True)

print("\n✅ 완료!")
# Out:
# GitHub Token:
#  ········
# 결과 파일 복사...
#   ✓ best.pt
#   ✓ last.pt
#   ✓ results.png
#   ✓ results.csv
#   ✓ confusion_matrix.png
#   ✓ confusion_matrix_normalized.png
#   ✓ data.yaml
#
# GitHub 푸시...
# Cloning into 'MCA'...
# Updating files: 100% (2033/2033), done.
# [main b530ebe] add: yolo11s_v7_highres_cls_focus (balanced, FP reduction, improvement: -10.79%)
#  8 files changed, 259 insertions(+)
#  create mode 100644 yolo11s_v7_highres_cls_focus/best.pt
#  create mode 100644 yolo11s_v7_highres_cls_focus/confusion_matrix.png
#  create mode 100644 yolo11s_v7_highres_cls_focus/confusion_matrix_normalized.png
#  create mode 100644 yolo11s_v7_highres_cls_focus/data.yaml
#  create mode 100644 yolo11s_v7_highres_cls_focus/last.pt
#  create mode 100644 yolo11s_v7_highres_cls_focus/performance_report.json
#  create mode 100644 yolo11s_v7_highres_cls_focus/results.csv
#  create mode 100644 yolo11s_v7_highres_cls_focus/results.png
#
# ✅ 완료!
# To https://github.com/ICT-Top-Bottom/MCA.git
#    80e45d4..b530ebe  main -> main
